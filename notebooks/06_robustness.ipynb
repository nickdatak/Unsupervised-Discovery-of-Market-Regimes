# %% [markdown]
# # 06 — Robustness (optional)
#
# Placeholder for walk-forward refit / L3 disclosure. Not implemented in this pipeline revision.

# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

sys.path.insert(0, str(Path.cwd().parent))
from regime_utils import *

print("Walk-forward refit: future work — refit GMM/HMM on expanding windows and compare stability.")
